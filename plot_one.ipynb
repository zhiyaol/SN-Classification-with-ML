# %%
from astropy.io import ascii
import matplotlib.pyplot as plt

rdr = ascii.get_reader(Reader=ascii.Basic)
rdr.header.splitter.delimiter = ' '
rdr.data.splitter.delimiter = ' '
rdr.header.start_line = 12
rdr.data.start_line = 13
rdr.data.end_line = None
t = rdr.read('DES_BLINDnoHOSTZ/DES_SN155300.DAT')
MJD = t['MJD']
FLT = t['FLT']
FIELD = t['FIELD']
FLUXCAL = t['FLUXCAL']
FLUXCALERR = t['FLUXCALERR']

plt.errorbar(MJD[FLT=='g'], FLUXCAL[FLT=='g'], FLUXCALERR[FLT=='g'], capsize = 4, label='g',color = 'forestgreen') 
plt.errorbar(MJD[FLT=='r'], FLUXCAL[FLT=='r'], FLUXCALERR[FLT=='r'], capsize = 4, label='r',color = 'coral')
plt.errorbar(MJD[FLT=='i'], FLUXCAL[FLT=='i'], FLUXCALERR[FLT=='i'], capsize = 4, label='i', color = 'indianred')
plt.errorbar(MJD[FLT=='z'], FLUXCAL[FLT=='z'], FLUXCALERR[FLT=='z'], capsize = 4, label='z', color = 'gray')
plt.title('SN000018 without host-galazy photo-z; SNTYPE: -9')
plt.xlabel('Modified Julian Date')
plt.ylabel('Calibrated Flux')

plt.legend()
plt.show()

# %%
t
# Out:
# <Table length=35>
# VARLIST:    MJD    FLT  FIELD FLUXCAL FLUXCALERR
#   str4    float64  str1  str4 float64  float64
# -------- --------- ---- ----- ------- ----------
#     OBS:  56282.16    g  NULL    -9.0       -9.0
#     OBS: 56282.184    r  NULL   1.465      2.179
#     OBS:  56287.16    i  NULL   10.06      4.991
#     OBS: 56287.191    z  NULL   17.17      3.908
#     OBS: 56289.035    g  NULL    -9.0       -9.0
#     OBS: 56289.043    r  NULL   2.522      4.185
#     OBS: 56289.152    i  NULL   19.59      4.345
#     OBS: 56289.176    z  NULL   15.48      4.474
#     OBS: 56297.039    g  NULL    -9.0       -9.0
#     OBS: 56297.047    r  NULL   17.48      1.274
#      ...       ...  ...   ...     ...        ...
#     OBS: 56333.051    r  NULL   8.433      1.397
#     OBS: 56334.043    i  NULL   26.72       2.24
#     OBS: 56335.043    z  NULL   23.82      3.411
#     OBS: 56344.992    g  NULL    -9.0       -9.0
#     OBS:   56345.0    r  NULL   4.379      1.864
#     OBS: 56345.016    i  NULL    20.1      3.474
#     OBS: 56345.992    z  NULL   18.12      3.715
#     OBS: 56349.996    g  NULL    -9.0       -9.0
#     OBS: 56350.004    r  NULL 0.09059      2.058
#     OBS: 56350.996    i  NULL   7.003      3.025
